# %%
from Compressor_map import Compressor
import numpy as np
import matplotlib.pyplot as plt

C = Compressor()

m_dp = 160
pi_C_dp = 310
eta_C_dp = 0.86

C.scale_map(m_dp=m_dp,  PR_dp=pi_C_dp, eta_dp=eta_C_dp)

plt.figure(1)
C.dispmap(map_type="PR",scaled = True ,x=m_dp, y=pi_C_dp)

plt.figure(2)
C.dispmap(map_type="eta", scaled = True ,x=m_dp, y=eta_C_dp)


plt.show()

# %%
from Turbine_map import Turbine


T = Turbine()

m_dp = 160
pi_T_dp = 310
eta_T_dp = 0.86

T.scale_map(m_dp=m_dp,  PR_dp=pi_C_dp, eta_dp=eta_C_dp)

plt.figure(1)
C.dispmap(map_type="PR",scaled = True ,x=m_dp, y=pi_C_dp)

plt.figure(2)
C.dispmap(map_type="eta", scaled = True ,x=m_dp, y=eta_C_dp)


plt.show()
